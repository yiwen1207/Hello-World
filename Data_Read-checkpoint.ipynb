# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Daily24_832lines_testset.csv")

# %%
df
# Out:
#      day_of_week       name.s  hour_end hour_start  mealsize.s  \
# 0              0      addFood  05:30:00   05:30:00  largeSnack
# 1              0      addFood  06:00:00   06:00:00  mediumMeal
# 2              0      addFood  06:30:00   06:30:00   largeMeal
# 3              0      addFood  06:30:00   06:30:00   smallMeal
# 4              0      addFood  07:00:00   07:00:00   largeMeal
# 5              0      addFood  07:30:00   07:30:00   smallMeal
# 6              0      addFood  07:30:00   07:30:00  smallSnack
# 7              0      addFood  08:00:00   08:00:00  mediumMeal
# 8              0      addFood  08:30:00   08:30:00  largeSnack
# 9              0      addFood  08:30:00   08:30:00  mediumMeal
# 10             0      addFood  08:30:00   08:30:00   smallMeal
# 11             0      addFood  08:30:00   08:30:00   smallMeal
# 12             0      addFood  08:30:00   08:30:00   smallMeal
# 13             0      addFood  09:00:00   09:00:00  mediumMeal
# ...

# %%
identifier = df["identifier"].unique()

# %%
unique, counts = np.unique(df["identifier"], return_counts=True)
counts_by_person = counts
